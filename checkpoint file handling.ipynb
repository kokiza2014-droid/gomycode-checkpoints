# %%
import numpy as np

# Lecture de la colonne 8
data = np.genfromtxt(
    r"C:\Users\MEDJAOUIS\Desktop\PERSO\Python\Loan_prediction_dataset.csv",
    delimiter=",",
    skip_header=1,
    usecols=[8]
)

# Calcul de la moyenne en ignorant les NaN
average = np.nanmean(data)
print("La moyenne est :", average)

# Calcul de la mediane en ignorant les NaN
mediane=np.nanmedian(data)
print("La mediane est :", mediane)

#Calcul de l'écart type nanstd
ecart=np.nanstd(data)
print("l'écart type est:",ecart)
# Out:
# La moyenne est : 146.41216216216216
# La mediane est : 128.0
# l'écart type est: 85.51500809120331
